# %%
# !pip3 install sagemaker

# %%
import sagemaker

# %%
sagemaker.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sagemaker.__version__
#
# AttributeError: module 'sagemaker' has no attribute '__version__'

# %%
sagemaker.model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sagemaker.model
#
# AttributeError: module 'sagemaker' has no attribute 'model'
